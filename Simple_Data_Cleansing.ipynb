# %% [markdown]
# # **INTRODUCTION**

# %% [markdown]
# ![Web capture_11-6-2022_134842_www.kaggle.com.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ‎Rms ‎‎Titanic‎‎ was a ‎‎British‎‎ ‎‎super passenger ship‎‎ that sank in the ‎‎North Atlantic Ocean‎‎ on 15 April 1912 after hitting an ‎‎iceberg‎‎ on ‎‎its maiden voyage‎‎ from ‎‎Southampton‎‎, England to ‎‎New York City‎‎. ‎‎The sinking of the ‎‎Titanic‎‎ resulted in the deaths of as many as 1,514 people in one of the deadliest ‎‎peacetime maritime disasters‎‎ in history. The Titanic was the largest ship in the world on its maiden voyage. One of the three ‎‎Olympic-class ocean liners is‎‎ operated by ‎‎the White Star Line‎‎. It was built from 1909 to 1911 by the ‎‎Harland and Wolff‎‎ shipyard in ‎‎Belfast‎‎. This ship is capable of carrying 2,224 passengers (Source: Wikipedia).‎
#
# The Titanic.csv file contains data for
# 891 Titanic passengers. Each row
# represents one person. The columns
# describe different attributes about
# the person including whether they
# survived, their age, their passengerclass, their sex, and the fare they paid

# %% [markdown]
# #**DATA CLEANSING**

# %% [markdown]
# In the early stages of data cleansing, I used several libraries, which are further described below and their functions.
#
# - **Pandas** = microsoft excel - data tabular
# - **Numpy** =  numerical computation
# - **Matpotlib, Seaborn** = visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# After importing the library, the next step is to import files.

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c2f12703-1934-4fd3-ba3d-e6f0fcf7c239" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c2f12703-1934-4fd3-ba3d-e6f0fcf7c239">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Titanic.csv to Titanic (2).csv
# ...

# %% [markdown]
# After that, reading the files that have been successfully imported using pandas

# %%
df = pd.read_csv("Titanic.csv")

# %% [markdown]
# At this stage, the data is checked by displaying several views to be checked. Is there missing data, noisy data and so on.

# %%
df.head() # See the top 5
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail() # See the bottom 5
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# After the inspection, several problems were found. Data cleansing is very necessary in this situation. The following shows more information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ##**Column Age**

# %% [markdown]
# In column age, a specific examination will be carried out on the data. In the first stage, a histogram will be visualized. A histogram is a graph that organizes and displays numerical data in the form of an image, showing groups of data and the amount or percentage of data that belongs to each group.

# %%
df['Age'].plot(kind='hist') # Visualize column age by using the histogram

# %% [markdown]
# After the visualization is done, the next step is to see the description of the data from the column age. At the description stage, several mathematical analyzes will be displayed such as the number, mean and so on

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# Based on these two specific examinations. It can be concluded that the histogram has a skewness distribution. This means that there is asymmetry (asymmetry) of a data distribution. The slope is divided into 3, namely symmetrical, tilted to the right and tilted to the left. The solution that can be applied to this problem is the imputation technique using the median so that the data distribution is even. The imputation technique is filling in the missing data with statistical techniques. While the median is the middle value of the sorted data.

# %%
val = df.Age.median()
df['Age'] = df.Age.fillna(val)

# %% [markdown]
# After that, a re-examination is carried out to ensure the quality of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ##**Column Cabin**

# %% [markdown]
# The number of data entries should be 891. But in the column cabin there are only 291. This means that there are quite a lot of null data in the column cabin. For further details, the proportion of data from the column cabin is shown.

# %%
df.Cabin.value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %% [markdown]
# After doing the proportion, there are a lot of missing values. So, the best solution that can be done is to delete the data or delete the column cabin. In addition, the data in the column cabin is also not very informative for further decisions

# %%
df.drop('Cabin', axis=1, inplace = True) # True (permanent)

# %% [markdown]
# Checking data again.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
#  11  Alone        891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ##**Column Embarked**

# %% [markdown]
# The case is the same as in the previous column. The total number of data entries is 891, while the embarked column is 889. This means that there are nulls in the embarked column

# %%
df.Embarked[df.Embarked.isnull()]
# Out:
# 61     NaN
# 829    NaN
# Name: Embarked, dtype: object

# %%
df.Embarked.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Embarked, Length: 891, dtype: bool

# %% [markdown]
# After that, display the proportion of data on the embarked column.

# %%
df.Embarked.value_counts() # Data proportion
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# After seeing the proportion, do the imputation by checking the data type first. It is known that the data type is categorical data, so the imputation uses the mode (mode) of the proportion on the embarked column data, namely S.

# %%
val = df.Embarked.mode().values[0]
df['Embarked'] = df.Embarked.fillna(val)

# %% [markdown]
# After the imputation, the proportion of the data has changed

# %%
df.Embarked.value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
#  11  Alone        891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ##**Column SibSp and Column Parch**

# %% [markdown]
# At this stage, perform data manipulation on the SibSp column and the Parch column. It aims to make it easier for the data to be read by the machine. The SibSp (Sibiling Spouse) column means the column that states the number of relatives or spouses brought by the passenger. The Parch column means the column that states the number of parents or the number of children carried by passengers. From these two columns, a new column can be made, which means that passengers board the ship themselves or bring their family or relatives.

# %%
# Add new Column as Alone
df['Alone'] = df['SibSp']+df['Parch']

# %%
df['Alone'][df['Alone']>0]='With Family'
df['Alone'][df['Alone']==0]='Without Family'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
#  11  Alone        891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked           Alone
# 0      0         A/5 21171   7.2500   NaN        S     With Family
# 1      0          PC 17599  71.2833   C85        C     With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Without Family
# ...

# %% [markdown]
# ##**Relation between Column Sex and Column Survived**

# %% [markdown]
# At this stage, we want to see the proportion of the relationship between column survived and column sex.

# %%
df.Sex[df['Survived']==1].value_counts()
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64

# %% [markdown]
# Then displayed in the form of a visualization using a bar chart.

# %%
df.Sex[df['Survived']==1].value_counts().plot(kind='bar')

# %% [markdown]
# Then compare with the column sex that did not survive

# %%
df.Sex[df['Survived']==0].value_counts()
# Out:
# male      468
# female     81
# Name: Sex, dtype: int64

# %% [markdown]
# Then visualization of the column sex that could not survive

# %%
df.Sex[df['Survived']==0].value_counts().plot(kind="bar");
